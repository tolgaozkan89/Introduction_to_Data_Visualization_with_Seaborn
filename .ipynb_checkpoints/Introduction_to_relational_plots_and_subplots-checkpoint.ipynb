# %% [markdown]
# # Introduction to relational plots and subplots

# %% [markdown]
# ##  ----  Quick Summary ----
# ## What are major import topics features?
# ### Important: relplot() lets you create subplots in a single
# ---
# ## -- Creating subplots with col and row --
# ### 1. sns.relplot(x="absences", y="G3",data=student_data,kind="scatter")
# ### 2. sns.relplot(x="absences",y="G3",data=student_data,kind="scatter",col="study_time")
# ### 3. sns.relplot(x="absences",y="G3",data=student_data,kind="scatter",row="study_time")
# ---
# ## ---- Creating two-factor subplots ----
# ### 1. sns.relplot(x="G1",y="G3",data=student_data,kind="scatter")
# ### 2. sns.relplot(x="G1",y="G3",data=student_data, kind="scatter",col="schoolsup",col_order=["yes","no"])
# ### 3. sns.relplot(x="G1",y="G3",data=student_data, kind="scatter",col="schoolsup",col_order=["yes","no"],row="famsup",row_order=["yes","no"])
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# %% [markdown]
# # PART1: "student-alcohol-consumption" DATASET

# %% [markdown]
# ## Q: Why use relplot() instead of scatterplot() ? /
# ## A: relplot() lets you create subplots in a single

# %%
student_data = pd.read_csv("student-alcohol-consumption.csv")

# %%
student_data.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         0  ...     4    1    1      3        6   5   6   6     Urban
# 1         0  ...     3    1    1      3        4   5   5   6     Urban
# 2         3  ...     2    2    3      3       10   7   8  10     Urban
# 3         0  ...     2    1    1      5        2  15  14  15     Urban
# 4         0  ...     2    1    2      5        4   6  10  10     Urban
#
#       study_time
# 0   2 to 5 hours
# 1   2 to 5 hours
# 2   2 to 5 hours
# 3  5 to 10 hours
# 4   2 to 5 hours
#
# ...

# %%
student_data.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %% [markdown]
# # 1. Creating subplots with col and row

# %% [markdown]
# # 1.1 scatterplot

# %%
sns.scatterplot(x="absences", y="G3",data=student_data)
plt.show()

# %% [markdown]
# # 1.2 relplot

# %% [markdown]
# Modify the code to use relplot() instead of scatterplot().

# %%
sns.relplot(x="absences", y="G3",data=student_data,kind="scatter")
plt.show()

# %% [markdown]
# # 1.2 + col="study_time"

# %% [markdown]
# Modify the code to create one scatter plot for each level of the variable "study_time", arranged in columns.

# %%
sns.relplot(x="absences",y="G3",data=student_data,kind="scatter",col="study_time")
plt.show()

# %% [markdown]
# # 1.3 + row="study_time"

# %% [markdown]
# Adapt your code to create one scatter plot for each level of a student's weekly study time, this time arranged in rows.

# %%
sns.relplot(x="absences",y="G3",data=student_data,kind="scatter",row="study_time")
plt.show()

# %% [markdown]
# # 2. Creating two-factor subplots

# %% [markdown]
# Use relplot() to create a scatter plot with "G1" on the x-axis and "G3" on the y-axis, using the student_data DataFrame.

# %%
sns.relplot(x="G1",y="G3",data=student_data,kind="scatter")

# %% [markdown]
# Create column subplots based on whether the student received support from the school ("schoolsup"), ordered so that "yes" comes before "no".

# %%
sns.relplot(x="G1",y="G3",data=student_data, kind="scatter",col="schoolsup",col_order=["yes","no"])
plt.show()

# %% [markdown]
# Add row subplots based on whether the student received support from the family ("famsup"), ordered so that "yes" comes before "no". This will result in subplots based on two factors.

# %%
sns.relplot(x="G1",y="G3",data=student_data, kind="scatter",col="schoolsup",col_order=["yes","no"],row="famsup",row_order=["yes","no"])
plt.show()
